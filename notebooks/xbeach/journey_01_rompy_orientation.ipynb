# %% [markdown]
# # Journey 1 — XBeach and Rompy: orientation
#
# **Learning goals:** Understand the Rompy model-run boundary and identify the XBeach workflow stages.
#
# **Prerequisites:** Basic Python. Install `rompy-xbeach` before executing the code cells.
#
# **Execution contract:** This lesson is render-only: it inspects package concepts and does not run XBeach.

# %%
import rompy_xbeach

print(f"rompy-xbeach {rompy_xbeach.__version__}")

# %% [markdown]
# ## Checkpoint
#
# - Continue with the [procedural workflow](../example-procedural/) and [Journey 2](../journey_02_xbeach_procedural/).

# %% [markdown]
# [Next: 2. Procedural workflow](../journey_02_xbeach_procedural/)
